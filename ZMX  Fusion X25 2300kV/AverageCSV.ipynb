# %%
import pandas as pd
import numpy as np

csv1 = "withLum5x4x3_2017-04-13_121436.csv"
csv2 = "withLum5x4x3_2017-04-13_121959.csv"
csv3 = "withHQ5x4x3_2017-04-13_123305.csv"

csvOut = "withHQ5x4x3_AVG.csv"

data1 = pd.read_csv(csv1)
data2 = pd.read_csv(csv2)
data3 = pd.read_csv(csv3)

l1, l2, l3 = len(data1.index), len(data2.index), len(data3.index)

maxIndex = l1
if(l1 > l2):
    maxIndex = l2
    if(l2 > l3):
        maxIndex = l3
        
data1 = data1[:maxIndex]
data2 = data2[:maxIndex]
data3 = data3[:maxIndex]
headers = list(data1)

seriesList = []
for i in range(0, maxIndex):
    vec1 = data1[i:i+1]
    vec2 = data2[i:i+1]
    vec3 = data3[i:i+1]
    vec_avg = []
    for col in headers:
        s = float(vec1[col]) + float(vec2[col]) + float(vec3[col])
        avg = s/3
        vec_avg.append(avg)
    seriesList.append(pd.Series(vec_avg, index=headers))
data = pd.DataFrame(seriesList, columns=headers)

data.to_csv(csvOut)

# %%
data
# Out:
#       Time (s)  ESC signal (µs)  Servo 1 (µs)  Servo 2 (µs)  Servo 3 (µs)  \
# 0     0.000000      1000.000000           NaN           NaN           NaN
# 1     0.171882      1000.000000           NaN           NaN           NaN
# 2     0.284908      1000.000000           NaN           NaN           NaN
# 3     0.412508      1000.000000           NaN           NaN           NaN
# 4     0.555612      1000.000000           NaN           NaN           NaN
# 5     0.671320      1000.000000           NaN           NaN           NaN
# 6     0.783140      1000.000000           NaN           NaN           NaN
# 7     0.896807      1000.000000           NaN           NaN           NaN
# 8     1.006707      1000.000000           NaN           NaN           NaN
# 9     1.123065      1000.000000           NaN           NaN           NaN
# 10    1.260677      1000.000000           NaN           NaN           NaN
# 11    1.487102      1000.000000           NaN           NaN           NaN
# ...
